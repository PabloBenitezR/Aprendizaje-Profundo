# %% [markdown]
# <a href="https://colab.research.google.com/github/gibranfp/CursoAprendizajeProfundo/blob/2026-1/notebooks/4a_gpt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torchmetrics

# %% [markdown]
# # Generative Pre-Trained Transformer (GPT)
#
# En esta libreta definiremos y entrenaremos un generador de texto a nivel caracter basado en bloques Transformer.

# %%
import os
import requests

import copy
from itertools import islice
from collections import Counter

import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

import torch as th
import torch.nn as nn
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader
from torch.optim import AdamW

from torchmetrics.text import Perplexity

from torch.utils.tensorboard import SummaryWriter

LR = 1e-3 # tasa de aprendizaje
WD = 1e-4 # weight decay
D_EMBED = 64 # tamaño de los embeddings
D_RDP = 4 * D_EMBED # tamaño de capa oculta de red hacia adelante por posición
N_CABEZAS = 4  # número de cabezas de autoatención
N_CAPAS = 4 # número de bloques Transformers
P_DROPOUT = 0.2 # Probabilidad de dropout

T_CONTEXTO = 32 # tamaño del contexto
MAXSEC = 2000 # tamaño máximo de secuencia ←en generación

T_LOTE = 64
N_EPOCAS = 30
LOGDIR = './logs/'
DC = 'cuda:0' if th.cuda.is_available() else 'cpu'

th.manual_seed(22)
np.random.seed(22)

# %% [markdown]
# ## Conjunto de datos
# Vamos a usar un conjunto de textos en español del CSIC, es un corpus de 146 millones de tokens compuesto por revistas científicas en español del repositorio [revistas.csic.es/](https://revistas.csic.es/).
#
# **Autores:** Petrea, Paul Andrei; De Gibert Bonet, Ona; Villegas, Marta
#
#
# Consta de 146.795.650 tokens, 4.395.368 oraciones y 30.929 documentos. Los documentos están separados por saltos de línea simples.
#
#
# fuente:https://zenodo.org/records/7313126

# %%
import os
import requests

os.makedirs("data", exist_ok=True)

url = "https://zenodo.org/records/7313126/files/csic_es.txt?download=1"
dest_path = os.path.join("data", "csic_es.txt")

with requests.get(url, stream=True) as r:
    r.raise_for_status()
    with open(dest_path, "wb") as f:
        for chunk in r.iter_content(chunk_size=8192):
            if chunk:
                f.write(chunk)

print("Descargado en:", dest_path)
# Out:
# Descargado en: data\csic_es.txt

# %% [markdown]
# La clase del iterable de dicho conjunto quedaría como:

# %%
from collections import Counter

class RevistasCiencia(Dataset):
  def __init__(self,
               path,
               context_size = 32,
               max_chars=None):

    self.PATH = path
    self.context_size = context_size

    if not os.path.exists(self.PATH):
      raise FileNotFoundError("No se encontro el archivo {self.PATH}")

    with open(self.PATH, 'r', encoding = 'utf-8') as f:
      text = f.read() # lee todo el contenido del archivo (textos)

    if max_chars is not None: # define una particion del archivo
      text = text[:max_chars]
    self.text = text

    # genera el vocabulario de caracteres
    self.voc = Counter([c for c in self.text])
    self.voc_size = len(self.voc)

    # Crea diccionarios para convertir de caracter a índice y viceversa
    self.i2c = {i:c for i,(c,f) in enumerate(self.voc.most_common())}
    self.c2i = {c:i for i,(c,f) in enumerate(self.voc.most_common())}

    # Convierte todo el texto de una cadena de caracteres a una lista de índices
    self.data = self.encode(self.text)

  def __getitem__(self, idx):
    # Toma la secuencia de context_size índices a partir de la posición idx
    # como entrada y la secuencia del mismo tamaño una posición recorrida a la
    # derecha como salida
    x = self.data[idx:idx + self.context_size]
    y = self.data[idx + 1:idx + self.context_size + 1]

    return x, y

  def __len__(self):
    return self.data.shape[0] - self.context_size

  def encode(self, t):
    # convierte cadena de caracteres en lista de índices
    return th.tensor([self.c2i[c] for c in t])

  def decode(self, l):
    # convierte lista de índices en cadena de caracteres
    return ''.join([self.i2c[i] for i in l])

# %% [markdown]
# Instanciamos el iterable y lo dividimos en subconjuntos de entrenamiento y validación usando la clase `Subset`.

# %%
ds = RevistasCiencia('data/csic_es.txt',context_size=T_CONTEXTO,max_chars=100_000_000)

STRIDE = 128

indices = np.arange(0, len(ds), step = STRIDE)

ent_ind, val_ind = train_test_split(indices,
                                    test_size = 0.1,
                                    shuffle = True,
                                    random_state = 42)

ent_ds = th.utils.data.Subset(ds, ent_ind)
val_ds = th.utils.data.Subset(ds, val_ind)

print("Tamaño vocabulario:", ds.voc_size)
print("Longitud dataset:", len(ds))
# Out:
# Tamaño vocabulario: 537
# Longitud dataset: 99999968

# %% [markdown]
# Desplagamos algunos elementos de ambos subconjuntos.

# %%
for x,y in islice(ent_ds, 100):
  print(x, y)
  print(ent_ds.dataset.decode(x.numpy()),
        ent_ds.dataset.decode(y.numpy()))

for x,y in islice(val_ds, 100):
  print(x, y)
  print(val_ds.dataset.decode(x.numpy()),
        val_ds.dataset.decode(y.numpy()))
# Out:
# tensor([ 0, 11, 12,  2,  5,  9,  3,  0,  9,  1,  4, 14, 12, 32,  4,  0,  9,  1,
#          0,  8,  2,  0,  5,  3, 10,  2,  0, 22,  6,  0,  5,  2]) tensor([11, 12,  2,  5,  9,  3,  0,  9,  1,  4, 14, 12, 32,  4,  0,  9,  1,  0,
#          8,  2,  0,  5,  3, 10,  2,  0, 22,  6,  0,  5,  2,  8])
#  cuando después de la nota fi na cuando después de la nota fi nal
# tensor([ 3,  0, 12,  5,  0, 10,  1, 36, 10,  3,  0, 11,  8, 27,  4,  6, 11,  3,
#          0, 19, 12,  1,  0,  4,  1,  0,  7,  1, 13,  3,  5, 10]) tensor([ 0, 12,  5,  0, 10,  1, 36, 10,  3,  0, 11,  8, 27,  4,  6, 11,  3,  0,
#         19, 12,  1,  0,  4,  1,  0,  7,  1, 13,  3,  5, 10,  2])
# o un texto clásico que se remont  un texto clásico que se remonta
# tensor([ 8,  2,  0,  9,  6, 18,  6,  4,  6, 23,  5,  0, 14,  7,  1,  4,  1,  5,
#         10,  2,  9,  2,  0,  1,  5,  0,  1,  8,  0, 37, 40, 41]) tensor([ 2,  0,  9,  6, 18,  6,  4,  6, 23,  5,  0, 14,  7,  1,  4,  1,  5, 10,
#          2,  9,  2,  0,  1,  5,  0,  1,  8,  0, 37, 40, 41, 34])
# la división presentada en el LIM a división presentada en el LIMC
# tensor([ 6, 28,  0,  3,  0,  2, 17, 12,  2,  9,  2,  4, 15,  0,  8,  3,  4,  0,
#         19, 12,  2,  8,  1,  4,  0, 16,  2,  8,  1,  5,  0, 20]) tensor([28,  0,  3,  0,  2, 17, 12,  2,  9,  2,  4, 15,  0,  8,  3,  4,  0, 19,
#         12,  2,  8,  1,  4,  0, 16,  2,  8,  1,  5,  0, 20,  0])
# iz o aguadas, los quales balen y z o aguadas, los quales balen y
#          8,  2,  0, 11,  2,  4,  2, 15,  0, 14, 12,  1,  4,  0])
#  la intirriidad de la casa, pues la intirriidad de la casa, pues
# tensor([ 4,  1,  4,  6, 23,  5,  0, 11,  6,  1,  5, 10, 26, 22,  6, 11,  2,  0,
#         20,  0, 10,  7,  2, 10,  2,  5,  0,  9,  1,  0,  3, 22]) tensor([ 1,  4,  6, 23,  5,  0, 11,  6,  1,  5, 10, 26, 22,  6, 11,  2,  0, 20,
#          0, 10,  7,  2, 10,  2,  5,  0,  9,  1,  0,  3, 22,  7])
# sesión científica y tratan de of esión científica y tratan de ofr
# tensor([ 9,  0,  9,  1,  0, 24,  2, 16,  1,  7,  0, 22,  7,  2, 17, 12,  2,  9,
#          3,  0, 32,  8, 15,  0, 14,  3,  7,  0,  4, 12,  4,  0]) tensor([ 0,  9,  1,  0, 24,  2, 16,  1,  7,  0, 22,  7,  2, 17, 12,  2,  9,  3,
#          0, 32,  8, 15,  0, 14,  3,  7,  0,  4, 12,  4,  0, 14])
# d de haber fraguado él, por sus   de haber fraguado él, por sus p
# tensor([ 1,  8,  1, 11, 10,  7, 23,  5,  6, 11,  2,  0, 20,  0,  2,  7, 13,  2,
#          4, 21, 25, 37,  3,  4,  0, 10,  2,  8,  8,  1,  7,  1]) tensor([ 8,  1, 11, 10,  7, 23,  5,  6, 11,  2,  0, 20,  0,  2,  7, 13,  2,  4,
#         21, 25, 37,  3,  4,  0, 10,  2,  8,  8,  1,  7,  1,  4])
# electrónica y armas.
# Los tallere lectrónica y armas.
# Los talleres
# tensor([24,  2, 11,  1,  7,  0, 12,  5,  2,  0,  8,  6,  4, 10,  2,  0,  9,  1,
#          0,  8,  6,  4, 10,  2,  4, 21, 25, 25,  1,  5,  0,  8]) tensor([ 2, 11,  1,  7,  0, 12,  5,  2,  0,  8,  6,  4, 10,  2,  0,  9,  1,  0,
#          8,  6,  4, 10,  2,  4, 21, 25, 25,  1,  5,  0,  8,  3])
# hacer una lista de listas.
#
# en l acer una lista de listas.
#
# en lo
# tensor([ 3,  5,  0,  4,  1, 17, 12,  7,  6,  9,  2,  9,  0, 14,  2,  7,  1, 11,
#          1,  0, 12,  5,  2,  0, 14,  7,  3, 14, 12,  1,  4, 10]) tensor([ 5,  0,  4,  1, 17, 12,  7,  6,  9,  2,  9,  0, 14,  2,  7,  1, 11,  1,
#          0, 12,  5,  2,  0, 14,  7,  3, 14, 12,  1,  4, 10,  2])
# on seguridad parece una propuest n seguridad parece una propuesta
# tensor([ 6,  5, 32,  7,  2,  6,  7,  1, 21, 25, 37,  3,  4,  0, 13,  3, 10,  6,
#         18,  3,  4,  0, 19, 12,  1,  0,  6,  8, 12,  4, 10,  7]) tensor([ 5, 32,  7,  2,  6,  7,  1, 21, 25, 37,  3,  4,  0, 13,  3, 10,  6, 18,
#          3,  4,  0, 19, 12,  1,  0,  6,  8, 12,  4, 10,  7,  2])
# inéraire.
# Los motivos que ilustr néraire.
# Los motivos que ilustra
# tensor([ 6, 17,  6,  3,  4,  2,  0, 11,  3, 13,  3,  0,  9,  3, 13, 32,  4, 10,
#          4,  1, 17, 12,  5,  9,  2,  0, 24,  6, 14, 23, 10,  1])
#  cabe plantear una segunda hipót cabe plantear una segunda hipóte
# tensor([ 6, 23,  5,  0,  9,  1,  0,  8,  3,  4,  0, 10,  1, 36, 10,  3,  4,  0,
#         17,  7,  6,  1, 17,  3,  4,  0, 20,  0,  8,  2, 10,  6]) tensor([23,  5,  0,  9,  1,  0,  8,  3,  4,  0, 10,  1, 36, 10,  3,  4,  0, 17,
#          7,  6,  1, 17,  3,  4,  0, 20,  0,  8,  2, 10,  6,  5])
# ión de los textos griegos y lati ón de los textos griegos y latin
# tensor([18,  1,  5,  1,  4,  0,  8,  2,  0,  9,  6,  4, 11,  6, 14,  8,  6,  5,
#          2,  0, 22, 26,  4,  6, 11,  2,  0, 20,  0,  1,  8,  0]) tensor([ 1,  5,  1,  4,  0,  8,  2,  0,  9,  6,  4, 11,  6, 14,  8,  6,  5,  2,
#          0, 22, 26,  4,  6, 11,  2,  0, 20,  0,  1,  8,  0, 11])
# venes la disciplina física y el  enes la disciplina física y el c
# tensor([11,  3, 13, 14,  2,  7,  2, 13,  3,  4,  0,  8,  2,  0, 11,  2,  5, 10,
#          6,  9,  2,  9,  0,  9,  1,  0,  3, 16,  7,  2,  4,  0]) tensor([ 3, 13, 14,  2,  7,  2, 13,  3,  4,  0,  8,  2,  0, 11,  2,  5, 10,  6,
#          9,  2,  9,  0,  9,  1,  0,  3, 16,  7,  2,  4,  0,  1])
# comparamos la cantidad de obras  omparamos la cantidad de obras e
# tensor([ 3,  0,  7,  3, 13,  2,  5,  3,  0,  5,  3,  0,  4,  1,  0, 24,  2,  5,
#          0,  9,  1, 10,  1, 11, 10,  2,  9,  3,  0,  2, 17,  8]) tensor([ 0,  7,  3, 13,  2,  5,  3,  0,  5,  3,  0,  4,  1,  0, 24,  2,  5,  0,
#          9,  1, 10,  1, 11, 10,  2,  9,  3,  0,  2, 17,  8, 12])
# o romano no se han detectado agl  romano no se han detectado aglu
# tensor([ 4,  0, 11, 12,  1,  7, 14,  3,  4,  0, 20,  0, 10,  7,  1,  4,  0, 11,
#          2,  8,  8,  1,  4, 15,  0,  7,  1, 13,  2, 10,  2,  9]) tensor([ 0, 11, 12,  1,  7, 14,  3,  4,  0, 20,  0, 10,  7,  1,  4,  0, 11,  2,
#          8,  8,  1,  4, 15,  0,  7,  1, 13,  2, 10,  2,  9,  2])
# s cuerpos y tres calles, rematad  cuerpos y tres calles, rematada
# tensor([ 0,  2,  5, 10,  1,  7,  6,  3,  7,  1,  4,  0,  5,  3,  4,  0,  1,  5,
#         11,  3,  5, 10,  7,  2, 13,  3,  4,  0, 11,  3,  5,  0]) tensor([ 2,  5, 10,  1,  7,  6,  3,  7,  1,  4,  0,  5,  3,  4,  0,  1,  5, 11,
#          3,  5, 10,  7,  2, 13,  3,  4,  0, 11,  3,  5,  0,  1])
#  anteriores nos encontramos con  anteriores nos encontramos con e
# tensor([ 1,  4, 10,  1,  8,  2,  4,  0,  4,  6,  5,  0,  6, 11,  3,  5,  3, 17,
#  sus ricos tesoros artísticos.In sus ricos tesoros artísticos.Ini
# tensor([11,  2, 16,  2,  8,  8,  1,  7,  3, 15,  0,  1,  4, 10,  1,  0,  1, 29,
#          1,  0,  4,  6, 17,  5,  6, 22,  6, 11,  2, 10,  6, 18]) tensor([ 2, 16,  2,  8,  8,  1,  7,  3, 15,  0,  1,  4, 10,  1,  0,  1, 29,  1,
#          0,  4,  6, 17,  5,  6, 22,  6, 11,  2, 10,  6, 18,  3])
# caballero, este eje significativ aballero, este eje significativo
# tensor([14,  3,  0, 14,  7,  6,  5, 11,  6, 14,  2,  8,  0, 20,  0,  1,  8,  0,
#         11,  1,  5, 10,  7,  3,  0,  8,  3,  0,  3, 11, 12, 14]) tensor([ 3,  0, 14,  7,  6,  5, 11,  6, 14,  2,  8,  0, 20,  0,  1,  8,  0, 11,
#          1,  5, 10,  7,  3,  0,  8,  3,  0,  3, 11, 12, 14,  2])
# po principal y el centro lo ocup o principal y el centro lo ocupa
# tensor([ 2, 10,  6, 18,  3, 69,  0,  8,  3,  4,  0, 10,  7,  1,  4,  0,  1, 13,
#         14,  8,  1,  2,  9,  3,  4,  0,  9,  1,  8,  0, 16,  2]) tensor([10,  6, 18,  3, 69,  0,  8,  3,  4,  0, 10,  7,  1,  4,  0,  1, 13, 14,
#          8,  1,  2,  9,  3,  4,  0,  9,  1,  8,  0, 16,  2,  5])
# ativo; los tres empleados del ba tivo; los tres empleados del ban
# tensor([ 8,  6,  5,  2,  0, 10,  2,  5,  0,  7,  6, 11,  2,  0, 19, 12,  1,  0,
#          1,  4, 10,  2,  0, 10,  2,  7,  1,  2,  0,  1, 36, 11]) tensor([ 6,  5,  2,  0, 10,  2,  5,  0,  7,  6, 11,  2,  0, 19, 12,  1,  0,  1,
#          4, 10,  2,  0, 10,  2,  7,  1,  2,  0,  1, 36, 11,  1])
# lina tan rica que esta tarea exc ina tan rica que esta tarea exce
# tensor([ 4,  0,  9,  1,  0, 11,  1,  5,  4, 12,  7,  2, 15,  0,  1, 10, 11, 21,
#         25, 56,  6,  1,  5,  1,  0, 14,  3,  7,  0, 48,  8, 10]) tensor([ 0,  9,  1,  0, 11,  1,  5,  4, 12,  7,  2, 15,  0,  1, 10, 11, 21, 25,
#         56,  6,  1,  5,  1,  0, 14,  3,  7,  0, 48,  8, 10,  6])
# s de censura, etc.
# Tiene por últ  de censura, etc.
# Tiene por últi
# tensor([ 2, 13,  6,  5,  3,  0,  1,  5,  0,  1,  8,  0, 19, 12,  1,  0,  4,  1,
#          0, 11,  3,  5, 22, 12,  5,  9,  1,  5,  0,  1,  8,  0]) tensor([13,  6,  5,  3,  0,  1,  5,  0,  1,  8,  0, 19, 12,  1,  0,  4,  1,  0,
#         11,  3,  5, 22, 12,  5,  9,  1,  5,  0,  1,  8,  0, 10])
# amino en el que se confunden el  mino en el que se confunden el t
# tensor([  0,  14,   2,   7,   1,  11,   1,   0,  19,  12,   1,   0,  68,   3,
#          15,   0,   2,  18,   2,   5,  11,   1, 105,   0,  24,   2,   5,   0,
# amiento de la de Sn.
# Juan Bautis miento de la de Sn.
# Juan Bautist
# tensor([11,  6, 23,  5, 50,  0, 12,  5,  3,  0,  9,  1,  0,  1,  8,  8,  3,  4,
#          0,  1,  4, 10, 27,  0, 11,  3, 13, 14, 12,  1,  4, 10]) tensor([ 6, 23,  5, 50,  0, 12,  5,  3,  0,  9,  1,  0,  1,  8,  8,  3,  4,  0,
#          1,  4, 10, 27,  0, 11,  3, 13, 14, 12,  1,  4, 10,  3])
# ción: uno de ellos está compuest ión: uno de ellos está compuesto
# tensor([11,  6, 12,  9,  2,  9,  0, 60, 61,  0, 93,  0, 63,  3,  4,  0, 24,  2,
#          8,  8,  2,  7, 26,  2, 13,  3,  4, 15,  0, 14,  3,  7]) tensor([ 6, 12,  9,  2,  9,  0, 60, 61,  0, 93,  0, 63,  3,  4,  0, 24,  2,  8,
#          8,  2,  7, 26,  2, 13,  3,  4, 15,  0, 14,  3,  7,  0])
# ciudad 47 • Nos hallaríamos, por iudad 47 • Nos hallaríamos, por
# tensor([ 2,  4,  0,  7,  3, 13,  2,  5,  2,  4, 15,  0,  1,  5,  0,  8,  2,  4,
#          0, 19, 12,  1,  0,  4,  1,  0, 22, 12,  5,  9,  2,  7]) tensor([ 4,  0,  7,  3, 13,  2,  5,  2,  4, 15,  0,  1,  5,  0,  8,  2,  4,  0,
#         19, 12,  1,  0,  4,  1,  0, 22, 12,  5,  9,  2,  7, 27])
# as romanas, en las que se fundar s romanas, en las que se fundará
# tensor([ 3,  0, 19, 12,  1, 21, 25, 67, 49,  0, 34,  6, 10,  2,  9,  3,  0, 14,
#          3,  7,  0, 35, 27,  5, 11, 24,  1, 28,  0, 34,  2,  5]) tensor([ 0, 19, 12,  1, 21, 25, 67, 49,  0, 34,  6, 10,  2,  9,  3,  0, 14,  3,
#          7,  0, 35, 27,  5, 11, 24,  1, 28,  0, 34,  2,  5, 10])
# o que.
# ^" Citado por Sánchez Can  que.
# ^" Citado por Sánchez Cant
# tensor([12, 11, 10, 12,  7,  2,  0, 74, 11,  6,  5,  1, 13,  2, 10,  3, 17,  7,
#         27, 22,  6, 11,  2, 74,  0, 20,  0, 19, 12,  1, 15,  0]) tensor([11, 10, 12,  7,  2,  0, 74, 11,  6,  5,  1, 13,  2, 10,  3, 17,  7, 27,
#         22,  6, 11,  2, 74,  0, 20,  0, 19, 12,  1, 15,  0,  2])
# uctura 'cinematográfica' y que,  ctura 'cinematográfica' y que, a
# tensor([ 1,  5,  9,  3,  0, 14,  7,  1, 11,  6, 14,  6, 10,  2,  9,  2, 13,  1,
#          5, 10,  1,  0,  9,  1,  0,  1,  8,  8,  3,  4,  0,  3]) tensor([ 5,  9,  3,  0, 14,  7,  1, 11,  6, 14,  6, 10,  2,  9,  2, 13,  1,  5,
#         10,  1,  0,  9,  1,  0,  1,  8,  8,  3,  4,  0,  3,  0])
# endo precipitadamente de ellos o ndo precipitadamente de ellos o
# tensor([12,  5,  2,  0,  2,  5, 10,  6, 17, 12,  2,  0, 13,  1, 28, 19, 12,  6,
#          1,  7,  4,  2,  8, 85, 25, 33,  0,  8,  2,  0, 11,  6]) tensor([ 2,  0,  8,  2,  0, 11,  6,  1,  5, 11,  6,  2,  0, 12,  5,  6, 18,  1,
#          7,  4,  2,  8, 85, 25, 33,  0,  8,  2,  0, 11,  6,  1])
#  a la ciencia universal?
# A la ci a la ciencia universal?
# A la cie
# tensor([ 0,  8,  3,  4,  0, 35, 12,  1, 43,  3,  4,  0,  9,  1,  0, 75, 12,  1,
#         18,  1,  9,  3, 15,  0, 19, 12,  1,  0, 24,  2, 11,  1]) tensor([ 8,  3,  4,  0, 35, 12,  1, 43,  3,  4,  0,  9,  1,  0, 75, 12,  1, 18,
#          1,  9,  3, 15,  0, 19, 12,  1,  0, 24,  2, 11,  1,  0])
#  los Sueños de Quevedo, que hace los Sueños de Quevedo, que hace
# tensor([ 2,  8, 13,  1,  5, 10,  1,  0,  4,  1,  0,  1,  5, 11, 12,  1,  5, 10,
#          7,  2,  5,  0,  9,  1, 14,  3,  4,  6, 10,  2,  9,  3]) tensor([ 8, 13,  1,  5, 10,  1,  0,  4,  1,  0,  1,  5, 11, 12,  1,  5, 10,  7,
#          2,  5,  0,  9,  1, 14,  3,  4,  6, 10,  2,  9,  3,  4])
# almente se encuentran depositado lmente se encuentran depositados
# tensor([51, 33, 42, 63, 30, 33, 21, 25, 44,  7,  3, 10,  3, 24,  6,  4, 10,  3,
#          7,  6,  2,  0,  9,  1,  0, 33,  5,  9,  2,  8, 12, 11]) tensor([33, 42, 63, 30, 33, 21, 25, 44,  7,  3, 10,  3, 24,  6,  4, 10,  3,  7,
#          6,  2,  0,  9,  1,  0, 33,  5,  9,  2,  8, 12, 11, 26])
# RA-NEA.
# Protohistoria de Andaluc A-NEA.
# Protohistoria de Andalucí
# tensor([ 5, 11,  8,  2, 18,  1,  0, 11,  3,  5,  0,  1,  8,  0, 11,  3,  5, 29,
#         12,  5, 10,  3,  0,  9,  1,  0, 35,  2,  5, 10,  2,  0]) tensor([11,  8,  2, 18,  1,  0, 11,  3,  5,  0,  1,  8,  0, 11,  3,  5, 29, 12,
#          5, 10,  3,  0,  9,  1,  0, 35,  2,  5, 10,  2,  0, 37])
# nclave con el conjunto de Santa  clave con el conjunto de Santa L
# tensor([13, 48,  4,  6, 11,  3,  4,  0,  1,  4, 14,  2, 43,  3,  8,  1,  4, 49,
#         15,  0, 11,  6, 10,  2,  9,  3,  0, 14,  3,  7,  0, 40]) tensor([48,  4,  6, 11,  3,  4,  0,  1,  4, 14,  2, 43,  3,  8,  1,  4, 49, 15,
#          0, 11,  6, 10,  2,  9,  3,  0, 14,  3,  7,  0, 40, 16])
# músicos españoles", citado por I úsicos españoles", citado por Ib
# tensor([28,  2,  9,  2,  4,  0, 20,  0, 19, 12,  1,  0, 11, 12,  1,  5, 10,  2,
#          5,  0, 11,  3,  5,  0, 13,  2, 20,  3,  7,  0,  2, 11]) tensor([ 2,  9,  2,  4,  0, 20,  0, 19, 12,  1,  0, 11, 12,  1,  5, 10,  2,  5,
#          0, 11,  3,  5,  0, 13,  2, 20,  3,  7,  0,  2, 11,  1])
# zadas y que cuentan con mayor ac adas y que cuentan con mayor ace
# tensor([10,  3,  4,  0, 10,  6, 14,  3,  4,  0,  9,  1,  0,  1,  4, 11,  1,  5,
#          2,  4, 21, 25, 30,  4, 10,  1,  0, 10,  7,  2, 16,  2]) tensor([ 3,  4,  0, 10,  6, 14,  3,  4,  0,  9,  1,  0,  1,  4, 11,  1,  5,  2,
#          4, 21, 25, 30,  4, 10,  1,  0, 10,  7,  2, 16,  2, 29])
# tos tipos de escenas.
# Este traba os tipos de escenas.
# Este trabaj
# tensor([ 4, 10,  2,  4,  0,  4,  1,  0,  2, 14,  7,  1, 11,  6,  2,  7, 27,  0,
#          4, 12,  0,  6,  5, 10,  1,  7,  7,  1,  8,  2, 11,  6]) tensor([10,  2,  4,  0,  4,  1,  0,  2, 14,  7,  1, 11,  6,  2,  7, 27,  0,  4,
#         12,  0,  6,  5, 10,  1,  7,  7,  1,  8,  2, 11,  6, 23])
# stas se apreciará su interrelaci tas se apreciará su interrelació
# tensor([ 5,  3, 11,  1,  7,  0,  2,  8, 17, 12,  5,  3,  4,  0,  2,  4, 14,  1,
#         11, 10,  3,  4,  0,  6,  5, 10,  1,  7,  1,  4,  2,  5]) tensor([ 3, 11,  1,  7,  0,  2,  8, 17, 12,  5,  3,  4,  0,  2,  4, 14,  1, 11,
#         10,  3,  4,  0,  6,  5, 10,  1,  7,  1,  4,  2,  5, 10])
# nocer algunos aspectos interesan ocer algunos aspectos interesant
# tensor([ 9,  0, 20,  0,  5, 12,  1,  4, 10,  7,  2,  0,  2,  9, 13,  6,  7,  2,
#         11,  6, 23,  5,  0,  2,  0,  4, 12,  0,  2, 12, 10,  3]) tensor([ 0, 20,  0,  5, 12,  1,  4, 10,  7,  2,  0,  2,  9, 13,  6,  7,  2, 11,
#          6, 23,  5,  0,  2,  0,  4, 12,  0,  2, 12, 10,  3,  7])
# d y nuestra admiración a su auto  y nuestra admiración a su autor
# tensor([ 6, 16, 12,  6,  9,  3,  4,  0,  2,  8,  0,  7,  1, 20,  0,  9,  2, 18,
#          6,  9, 21, 25, 30,  8,  0, 14,  1,  7,  4,  3,  5,  2]) tensor([16, 12,  6,  9,  3,  4,  0,  2,  8,  0,  7,  1, 20,  0,  9,  2, 18,  6,
#          9, 21, 25, 30,  8,  0, 14,  1,  7,  4,  3,  5,  2, 29])
# ibuidos al rey david.
# El persona buidos al rey david.
# El personaj
# tensor([ 3, 28, 11,  2,  0,  2, 48,  5,  0,  1,  8,  0,  6, 13, 14,  7,  1,  4,
#          3,  0, 20,  0,  9,  1,  4,  1,  1,  0,  1,  5, 11,  3]) tensor([28, 11,  2,  0,  2, 48,  5,  0,  1,  8,  0,  6, 13, 14,  7,  1,  4,  3,
#          0, 20,  0,  9,  1,  4,  1,  1,  0,  1,  5, 11,  3,  5])
# ozca aún el impreso y desee enco zca aún el impreso y desee encon
# tensor([ 9, 32, 13,  6, 11,  2,  0, 20,  0, 11,  6,  1,  5, 10, 26, 22,  6, 11,
# impiar de un Principe el quarto/ mpiar de un Principe el quarto/
# tensor([ 7,  3, 14,  6,  3,  0, 10, 26, 10, 12,  8,  3,  0,  9,  1,  0,  4, 12,
#          0,  3, 16,  7,  2, 15,  0, 11,  3,  4,  2,  0, 19, 12]) tensor([ 3, 14,  6,  3,  0, 10, 26, 10, 12,  8,  3,  0,  9,  1,  0,  4, 12,  0,
#          3, 16,  7,  2, 15,  0, 11,  3,  4,  2,  0, 19, 12,  1])
# ropio título de su obra, cosa qu opio título de su obra, cosa que
# tensor([ 1,  4, 14,  3,  5,  9,  1,  0,  2,  0,  8,  2,  0,  5, 12,  1, 18,  2,
#          0, 32, 14,  3, 11,  2,  0, 13,  2, 19, 12,  6,  2, 18]) tensor([ 4, 14,  3,  5,  9,  1,  0,  2,  0,  8,  2,  0,  5, 12,  1, 18,  2,  0,
#         32, 14,  3, 11,  2,  0, 13,  2, 19, 12,  6,  2, 18, 32])
# esponde a la nueva época maquiav sponde a la nueva época maquiavé
# tensor([ 0,  7,  1, 14,  7,  1,  4,  1,  5, 10,  2,  5,  0,  8,  2,  0, 29, 12,
#          5, 10,  2,  0,  9,  1,  0, 10,  1,  4, 10,  2,  0, 11]) tensor([ 7,  1, 14,  7,  1,  4,  1,  5, 10,  2,  5,  0,  8,  2,  0, 29, 12,  5,
#         10,  2,  0,  9,  1,  0, 10,  1,  4, 10,  2,  0, 11,  3])
#  representan la junta de testa c representan la junta de testa co
# tensor([ 2, 11,  3, 13, 14,  2, 43,  2,  7, 15,  0,  2,  4,  6, 13,  6,  4, 13,
#          3, 15,  0, 12,  5,  0,  1,  4, 10, 12,  9,  6,  3,  0]) tensor([11,  3, 13, 14,  2, 43,  2,  7, 15,  0,  2,  4,  6, 13,  6,  4, 13,  3,
#         15,  0, 12,  5,  0,  1,  4, 10, 12,  9,  6,  3,  0,  9])
# acompañar, asimismo, un estudio  compañar, asimismo, un estudio d
# tensor([15,  0,  9,  1,  0, 24,  1, 11, 24,  3, 15,  0,  8,  2,  4,  0, 14,  6,
#          5, 10, 12,  7,  2,  4,  0,  9,  1,  0, 55,  2,  5,  9]) tensor([ 0,  9,  1,  0, 24,  1, 11, 24,  3, 15,  0,  8,  2,  4,  0, 14,  6,  5,
#         10, 12,  7,  2,  4,  0,  9,  1,  0, 55,  2,  5,  9,  1])
# , de hecho, las pinturas de Vand  de hecho, las pinturas de Vande
# tensor([ 1,  0,  2,  0, 18,  1, 11,  1,  4,  0,  4,  1,  0,  9,  1,  4, 17,  2,
#         29,  2,  0, 12,  5,  3, 15,  0,  9,  3,  4, 15,  0,  3]) tensor([ 0,  2,  0, 18,  1, 11,  1,  4,  0,  4,  1,  0,  9,  1,  4, 17,  2, 29,
#          2,  0, 12,  5,  3, 15,  0,  9,  3,  4, 15,  0,  3,  0])
# e a veces se desgaja uno, dos, o  a veces se desgaja uno, dos, o
# ...
#          5,  0,  9,  1,  0,  8,  3,  4,  0,  6,  5, 13,  6, 17])
# sa de la integración de los inmi a de la integración de los inmig
#          8,  1, 18,  2,  5,  0,  2,  0,  2, 22,  6,  7, 13,  2])
# as su muerte, nos llevan a afirm s su muerte, nos llevan a afirma
# tensor([11,  3,  5, 22,  6,  7, 13,  2, 16,  2,  0,  1,  5,  0, 12,  5,  2,  0,
#         11,  3,  8,  1, 11, 11,  6, 23,  5,  0, 11,  3,  5, 11]) tensor([ 3,  5, 22,  6,  7, 13,  2, 16,  2,  0,  1,  5,  0, 12,  5,  2,  0, 11,
#          3,  8,  1, 11, 11,  6, 23,  5,  0, 11,  3,  5, 11,  7])
# confirmaba en una colección conc onfirmaba en una colección concr
# tensor([ 2, 13, 16,  6, 32,  5,  0,  9,  3,  5,  0, 68, 12,  2,  5,  0, 20,  0,
#          9,  3,  5,  0, 33,  5, 10,  3,  5,  6,  3,  0, 18,  3]) tensor([13, 16,  6, 32,  5,  0,  9,  3,  5,  0, 68, 12,  2,  5,  0, 20,  0,  9,
#          3,  5,  0, 33,  5, 10,  3,  5,  6,  3,  0, 18,  3,  8])
# ambién don Juan y don Antonio vo mbién don Juan y don Antonio vol
# tensor([ 4,  0,  9,  1,  0,  6,  4, 23, 10,  3, 14,  3,  4,  0,  9,  1,  0, 14,
#          8,  3, 13,  3, 15,  0,  4,  1,  0, 14, 12,  1,  9,  1]) tensor([ 0,  9,  1,  0,  6,  4, 23, 10,  3, 14,  3,  4,  0,  9,  1,  0, 14,  8,
#          3, 13,  3, 15,  0,  4,  1,  0, 14, 12,  1,  9,  1,  5])
# s de isótopos de plomo, se puede  de isótopos de plomo, se pueden
# tensor([ 2, 16,  6,  9,  3,  0,  1,  5, 11,  3,  5, 10,  7,  2,  7,  0, 12,  5,
#          2,  0,  5, 12,  1, 18,  2,  0,  9,  6, 13,  1,  5,  4]) tensor([16,  6,  9,  3,  0,  1,  5, 11,  3,  5, 10,  7,  2,  7,  0, 12,  5,  2,
#          0,  5, 12,  1, 18,  2,  0,  9,  6, 13,  1,  5,  4,  6])
# abido encontrar una nueva dimens bido encontrar una nueva dimensi
# tensor([ 3,  7,  0,  9,  1,  4, 24,  3,  5,  7,  2,  0,  1,  8,  0,  3, 22,  6,
#         11,  6,  3,  0, 13,  1, 11, 27,  5,  6, 11,  3, 15,  0]) tensor([ 7,  0,  9,  1,  4, 24,  3,  5,  7,  2,  0,  1,  8,  0,  3, 22,  6, 11,
#          6,  3,  0, 13,  1, 11, 27,  5,  6, 11,  3, 15,  0, 14])
# or deshonra el oficio mecánico,  r deshonra el oficio mecánico, p
# tensor([26,  2,  0,  4,  6,  9,  3,  0, 12,  5,  0, 22,  7,  2, 12,  9,  1, 21,
#         25, 78,  0,  8,  3,  0, 24,  2, 11,  1,  0, 29, 12,  4]) tensor([ 2,  0,  4,  6,  9,  3,  0, 12,  5,  0, 22,  7,  2, 12,  9,  1, 21, 25,
#         78,  0,  8,  3,  0, 24,  2, 11,  1,  0, 29, 12,  4, 10])
# ía sido un fraude.
# Y lo hace jus a sido un fraude.
# Y lo hace just
# tensor([ 6, 23,  5,  0, 14,  3,  8,  6, 32,  9,  7,  6, 11,  2,  0,  9,  1,  8,
#          0, 22,  1,  5, 23, 13,  1,  5,  3,  0, 24,  6,  4, 10]) tensor([23,  5,  0, 14,  3,  8,  6, 32,  9,  7,  6, 11,  2,  0,  9,  1,  8,  0,
#         22,  1,  5, 23, 13,  1,  5,  3,  0, 24,  6,  4, 10, 23])
# ión poliédrica del fenómeno hist ón poliédrica del fenómeno histó
# tensor([16,  6, 32,  5,  0,  8,  2,  0, 10,  3,  7,  7,  1,  0,  4,  1,  0,  9,
#          1,  4, 14,  8,  2, 28,  2,  0,  6,  5, 10,  1,  5, 11]) tensor([ 6, 32,  5,  0,  8,  2,  0, 10,  3,  7,  7,  1,  0,  4,  1,  0,  9,  1,
#          4, 14,  8,  2, 28,  2,  0,  6,  5, 10,  1,  5, 11,  6])
# bién la torre se desplaza intenc ién la torre se desplaza intenci
# tensor([ 6,  3,  0,  2, 29,  1,  5,  3,  0, 20,  0,  1,  5, 10,  6,  1,  5,  9,
#          1,  0, 19, 12,  1,  0,  4, 12,  0,  9, 12,  1, 43,  3]) tensor([ 3,  0,  2, 29,  1,  5,  3,  0, 20,  0,  1,  5, 10,  6,  1,  5,  9,  1,
#          0, 19, 12,  1,  0,  4, 12,  0,  9, 12,  1, 43,  3,  0])
# io ajeno y entiende que su dueño o ajeno y entiende que su dueño
# tensor([31, 53, 45, 45, 15,  0, 41,  2, 10,  1,  3,  0, 64,  8,  1, 11, 24,  2,
#          0,  1,  4,  0,  5,  3, 13, 16,  7,  2,  9,  3,  0, 11]) tensor([53, 45, 45, 15,  0, 41,  2, 10,  1,  3,  0, 64,  8,  1, 11, 24,  2,  0,
#          1,  4,  0,  5,  3, 13, 16,  7,  2,  9,  3,  0, 11,  2])
# 1522, Mateo Flecha es nombrado c 522, Mateo Flecha es nombrado ca
# tensor([ 0,  8,  2,  0, 13,  1,  9,  6,  2,  0,  9,  1,  8,  0, 34, 35, 40, 34,
#         15,  0,  5,  3,  0, 24,  2, 16,  6,  1,  5,  9,  3,  0]) tensor([ 8,  2,  0, 13,  1,  9,  6,  2,  0,  9,  1,  8,  0, 34, 35, 40, 34, 15,
#          0,  5,  3,  0, 24,  2, 16,  6,  1,  5,  9,  3,  0, 13])
#  la media del CSIC, no habiendo  la media del CSIC, no habiendo m
# tensor([ 0, 10,  2,  8,  0, 20,  0, 11,  3, 13,  3,  0,  3, 11, 12,  7,  7,  1,
#          0,  1,  5,  0,  3, 10,  7,  2,  4,  0,  2, 16,  7,  1]) tensor([10,  2,  8,  0, 20,  0, 11,  3, 13,  3,  0,  3, 11, 12,  7,  7,  1,  0,
#          1,  5,  0,  3, 10,  7,  2,  4,  0,  2, 16,  7,  1, 18])
#  tal y como ocurre en otras abre tal y como ocurre en otras abrev
# tensor([13,  1,  5, 10,  1,  0, 14,  2,  7,  1, 11,  1,  5,  0, 11,  3,  6,  5,
#         11,  6,  9,  6,  7,  0, 11,  3,  5,  0, 13,  3, 13,  1]) tensor([ 1,  5, 10,  1,  0, 14,  2,  7,  1, 11,  1,  5,  0, 11,  3,  6,  5, 11,
# tensor([ 6, 22, 12,  5,  9,  6, 23,  0,  1,  5,  0,  8,  2,  0, 14,  7,  1,  5,
#          4,  2,  0,  8,  3, 11,  2,  8,  0,  2,  0, 14,  2,  7]) tensor([22, 12,  5,  9,  6, 23,  0,  1,  5,  0,  8,  2,  0, 14,  7,  1,  5,  4,
#          2,  0,  8,  3, 11,  2,  8,  0,  2,  0, 14,  2,  7, 10])
# ifundió en la prensa local a par fundió en la prensa local a part
# tensor([ 8,  0, 18,  3, 11,  2, 16, 12,  8,  2,  7,  6,  3,  0, 18,  2,  4, 11,
#          3,  0, 11,  3,  6,  5, 11,  6,  9,  1,  5, 10,  1,  4]) tensor([ 0, 18,  3, 11,  2, 16, 12,  8,  2,  7,  6,  3,  0, 18,  2,  4, 11,  3,
#          0, 11,  3,  6,  5, 11,  6,  9,  1,  5, 10,  1,  4,  0])
# l vocabulario vasco coincidentes  vocabulario vasco coincidentes
# tensor([ 2,  8,  0, 18,  1, 28,  0, 24,  2, 20,  2,  0,  4,  6,  9,  3,  0,  8,
#          2,  0,  3, 14,  3,  7, 10, 12,  5,  6,  9,  2,  9,  0]) tensor([ 8,  0, 18,  1, 28,  0, 24,  2, 20,  2,  0,  4,  6,  9,  3,  0,  8,  2,
#          0,  3, 14,  3,  7, 10, 12,  5,  6,  9,  2,  9,  0,  9])
# al vez haya sido la oportunidad  l vez haya sido la oportunidad d
# tensor([ 1,  7,  0,  4,  2, 11,  7,  2,  8,  6, 28,  2,  9,  3,  4,  0, 20,  0,
#         11,  3,  5, 18,  1,  7, 10,  6,  9,  3,  4,  0,  1,  5]) tensor([ 7,  0,  4,  2, 11,  7,  2,  8,  6, 28,  2,  9,  3,  4,  0, 20,  0, 11,
#          3,  5, 18,  1,  7, 10,  6,  9,  3,  4,  0,  1,  5,  0])
# er sacralizados y convertidos en r sacralizados y convertidos en
# tensor([ 4,  3, 16,  7,  1,  0, 12,  5,  0, 34,  7,  6,  4, 10,  3,  0, 13, 12,
#          1,  7, 10,  3,  0,  1,  5,  0, 16,  7,  2, 28,  3,  4]) tensor([ 3, 16,  7,  1,  0, 12,  5,  0, 34,  7,  6,  4, 10,  3,  0, 13, 12,  1,
#          7, 10,  3,  0,  1,  5,  0, 16,  7,  2, 28,  3,  4,  0])
# sobre un Cristo muerto en brazos obre un Cristo muerto en brazos

# %% [markdown]
# Creamos los cargadores de datos para los subconjuntos de entrenamiento y validación.

# %%
entdl = DataLoader(ent_ds,
                   batch_size = T_LOTE,
                   shuffle = False,
                   drop_last = True)

valdl = DataLoader(val_ds,
                   batch_size = T_LOTE,
                   shuffle = False,
                   drop_last = False)

# %% [markdown]
# ## Arquitectura
# Definiremos una versión muy pequeña de GPT, basada en [nanoGPT](https://github.com/karpathy/nanoGPT) de Andrej Karpathy.
#
# ### Producto punto escalado con enmascaramiento
# La función de puntaje del producto punto escalado entre el $i$-ésimo vector de consulta $\mathbf{q}^{[i]}\in \mathbb{R}^{d_k}$ y el $j$-ésimo vector de llave $\mathbf{k}^{[j]} \in \mathbb{R}^{d_k}$ está definida como:
# $$
# puntaje(\mathbf{q}^{[i]}, \mathbf{k}^{[j]}) = \frac{\mathbf{q}^{[i] \top} \mathbf{k}^{[j]}}{\sqrt{d_k}},
# $$
#
# donde $i,j \in [1, \ldots, T]$. Su valor de atención $\alpha_{i,j}$ está dado por:
# $$
# \alpha_{i,j} = softmax\left(puntaje(\mathbf{q}^{[i]}, \mathbf{k}^{[j]})\right)
# $$
#
# Para evitar que el modelo observe palabras que se encuentran más adelante en la secuencia durante la generación autoregresiva, se multiplica la matriz de atentión por una máscara (matriz binaria).
#
# <img src="https://peterbloem.nl/files/transformers/masked-attention.svg">
#
# Imagen tomada de [https://peterbloem.nl/blog/transformers](https://peterbloem.nl/blog/transformers).

# %%
class ProductoPuntoEscalado(nn.Module):
  def __init__(self,
               p_dropout = 0.0,
               masc = False):
    super(ProductoPuntoEscalado, self).__init__()
    self.masc = masc
    self.dropout = nn.Dropout(p_dropout)

  def forward(self, Q, K, V):
    # Obtenemos dimensiones
    m, n_cabezas, l, d_k = K.shape
    d_v = V.shape[-1]

    # Cambiamos la forma de Q, K y V para calcular el producto punto
    # [m, n_cabezas, l, d_k] -> [m * n_cabezas, l, d_k]
    Q = Q.reshape(m * n_cabezas, l, d_k)
    K = K.reshape(m * n_cabezas, l, d_k)
    V = V.reshape(m * n_cabezas, l, d_v)

    # Q y K tienen forma [m * n_cabezas, l, d_k] a [m * n_cabezas, d_k, l],
    # por lo que se transponen las dos últimas dimensiones de K de
    # [m * n_cabezas, l, d_k] para pasarlas a la función bmm (multiplicación
    # de lotes de matrices). Esta función multiplica cada una de las m * n_cabezas
    # matrices de lxd_k en Q con la correspondiente  matriz de d_kxl en la
    # transpuesta de K, resultando en m * n_cabezas matrices de lxl.
    # QK.T: [m * n_cabezas, l, l]
    QK = th.bmm(Q, K.transpose(1, 2))

    # se escalan los valores QK dividiendo entre sqrt(d_k)
    QK_esc = QK / th.math.sqrt(d_k)

    if self.masc:
      # Creamos una matriz triangular superior binaria (excluyendo la diagonal)
      masc = th.triu(th.ones((l, l), dtype = th.bool, device = Q.device),
                     diagonal = 1)
      # Ponemos los valores de QK_esc en los que la máscara sea 1 a -inf
      QK_esc = QK_esc.masked_fill_(masc, -th.inf)

    # se aplica la función softmax sobre la última dimensión de los mapas
    # de atención.
    # [m * n_cabezas, l, l] -> [m * n_cabezas, l, l]
    alfas = nn.functional.softmax(QK_esc, dim = -1)

    # Se agrega dropout de acuerdo al codigo de nanoGPT
    alfas = self.dropout(alfas)

    # Se calculan los vectores de salida como la suma de todos los vectores
    # V en cada cabeza multiplicados por sus mapas de atención. Esto se
    # realiza usando la función bmm, la cual multiplica cada una de las m * n_cabezas
    # matrices de lxl en alfas con la correspondiente matriz de lxd_v en V,
    # resultando en m * n_cabezas matrices de lxd_v.
    # alfas: [m * n_cabezas, l, l], V: [m * n_cabezas, l, d_v]
    # Y: [m * n_cabezas, l, d_v]
    Y = th.bmm(alfas, V)

    # Desagrupamos las dimensiones de ejemplos y de cabezas en los mapas de atención
    # [m * n_cabezas, l, d_v] -> [m, n_cabezas, l, d_v]
    Y = Y.reshape(m, n_cabezas, l, d_v)

    # Desagrupamos las dimensiones de ejemplos y de cabezas en los mapas de atención
    # [m * n_cabezas, l, l] -> [m, n_cabezas, l, l]
    alfas = alfas.reshape(m, n_cabezas, l, l)

    return Y, alfas

ppe = ProductoPuntoEscalado()
ppe(th.rand([1, 4, 10, 64]), # Q
    th.rand([1, 4, 10, 64]), # K
    th.rand([1, 4, 10, 64]))[0].shape # V
# Out:
# torch.Size([1, 4, 10, 64])

# %% [markdown]
# ### Atención multicabeza
# En la autoatención de la arquitectura Transformer, cada vector $\mathbf{x}^{[i]} \in \mathbb{R}^{d_{modelo} \times 1}$ en la secuencia se transforma a tres usando las matrices entrenables $\mathbf{W}_q \in \mathbb{R}^{d_k \times d_{modelo}}$, $\mathbf{W}_k \in \mathbb{R}^{d_k \times d_{modelo}}$ y $\mathbf{W}_v \in \mathbb{R}^{d_v \times d_{modelo}}$: uno conocido como consulta $\mathbf{q}^{[i]} \in \mathbb{R}^{d_k \times 1}$, otro como llave $\mathbf{k}^{[i]} \in \mathbb{R}^{d_k \times 1}$ y un tercero como valor $\mathbf{v}^{[i]} \in \mathbb{R}^{d_k \times 1}$:
#
# \begin{align*}
# \mathbf{q}^{[i]} & = \mathbf{W}_q \mathbf{x}^{[i]}\\
# \mathbf{k}^{[i]} & =  \mathbf{W}_k \mathbf{x}^{[i]}\\
# \mathbf{v}^{[i]} & = \mathbf{W}_v \mathbf{x}^{[i]}
# \end{align*}
#
# El $i$-ésimo vector de salida $\mathbf{a}^{[i]} \in \mathbb{R}^{d_v \times 1}$ en la secuencia se obtiene calculando la suma de cada vector de valor $\mathbf{v}^{[j]}$ ponderado por su valor de atención $\alpha_{i,j}$:
# $$
# \mathbf{a}^{[i]} = \sum_{j=1}^T \alpha_{i,j}\cdot \mathbf{v}^{[j]}
# $$
#
# Para llevar a cabo la atención multicabeza, esta operación se lleva a cabo con $h$ matrices entrenables distintas y se concatenan los $h$ vectores de salida resultantes de la $i$-ésima posición en un vector solo vector $\mathbf{o}^{[i]} \in \mathbb{R}^{(h \cdot d_v) \times 1}$:
# $$
# \mathbf{o}^{[i]} = [\mathbf{a}^{[i]}_1;\cdots;\mathbf{a}^{[i]}_h]
# $$
#
# Este vector se multiplica por la matriz entrenable $\mathbf{W}_o \in \mathbb{R}^{d_{modelo} \times (h \cdot d_v)}$ para producir el vector de salida $\mathbf{y}^{[i]}  \in \mathbb{R}^{d_{modelo} \times 1}$ de la autoatención multicabeza:
#
# $$
# \mathbf{y}^{[i]} = \mathbf{W}_o \cdot \mathbf{o}^{[i]}
# $$
#
# <img src="https://machinelearningmastery.com/wp-content/uploads/2021/09/tour_4.png">
#
# Imagen tomada de https://arxiv.org/abs/1706.03762

# %%
class AtencionMulticabeza(nn.Module):
  def __init__(self,
               d_modelo,
               n_cabezas,
               p_dropout = 0.0,
               masc = False):
    super(AtencionMulticabeza, self).__init__()

    self.n_cabezas = n_cabezas
    self.d_modelo = d_modelo

    self.d_k = self.d_modelo // self.n_cabezas

    self.ppe = ProductoPuntoEscalado(p_dropout = p_dropout, masc = masc)

    self.proy_Q = nn.Linear(self.d_modelo, self.d_modelo, bias = False)
    self.proy_K = nn.Linear(self.d_modelo, self.d_modelo, bias = False)
    self.proy_V = nn.Linear(self.d_modelo, self.d_modelo, bias = False)

    self.proy_sal = nn.Linear(self.d_modelo, self.d_modelo)

  def forward(self, x):
    m, l, d_modelo = x.shape

    # Cambiamos la forma del tensor de entrada x
    # para proyectarlo con Wq, Wk y Wv
    # [m, l, d_modelo] -> [m * l, d_modelo]
    x = x.reshape(m * l, d_modelo)

    # Proyectamos vectores en x a Q, K, V
    # [m * l, d_modelo] -> [m * l, d_modelo]
    Q = self.proy_Q(x)
    K = self.proy_K(x)
    V = self.proy_V(x)

    # Dividimos vectores de d_modelo en n_cabezas
    # de d_k.
    # [m, l, d_modelo] -> [m, l, n_cabezas, d_k]
    # d_k = d_v = self.d_modelo // self.n_cabezas
    Q = Q.reshape(m, l, self.n_cabezas, self.d_k)
    K = K.reshape(m, l, self.n_cabezas, self.d_k)
    V = V.reshape(m, l, self.n_cabezas, self.d_k)

    # Transponemos el eje de las cabezas a la segunda posición del tensor
    # y el de la secuencia a la tercera para pasarlo por el producto punto
    # escalado. Creamos copia (con .contiguous()) para que esté almacenado
    # en memoria de forma contigua (.transpose() hace que ya no sea así).
    # [m, l, n_cabezas, d_k] -> [m, n_cabezas, l, d_k]
    Q = Q.transpose(1, 2).contiguous()
    K = K.transpose(1, 2).contiguous()
    V = V.transpose(1, 2).contiguous()

    # Calculamos el producto punto escalado con Q, K y V
    # Q, K, Y: [m, n_cabezas, l, d_k], V:[m, n_cabezas, l, d_k]
    Y, alfas = self.ppe(Q, K, V)

    # Regresamos el eje de cabezas a la tercera posición y el de la
    # secuencia a la segundo (como estaba originalmente).
    # [m, n_cabezas, l, d_k] -> [m, l, n_cabezas, d_k]
    Y = Y.transpose(1, 2).contiguous()

    # Concatemanos los vectores de todas las cabezas en un solo vector
    # para pasarlos por la capa de proyección de salida Wo, agrupando
    # dimensiones de ejemplos y secuencia.
    # [m, l, n_cabezas, d_k] -> [m * l, d_modelo]
    # d_modelo = n_cabezas * d_k
    Y = Y.reshape(m * l, self.d_modelo)

    # Proyectamos la vectores concatenados para obtener la salida
    # [m * l, d_modelo] -> [m * l, d_modelo]
    Y = self.proy_sal(Y)

    # Desagrupamos dimensiones de ejemplos y secuencia
    # [m * l, d_modelo] -> [m, l, d_modelo]
    Y = Y.reshape(m, l, self.d_modelo)

    return Y, alfas

amc = AtencionMulticabeza(256, 2)
amc(th.rand([1, 10, 256]))[0].shape
# Out:
# torch.Size([1, 10, 256])

# %% [markdown]
# ### Red hacia adelante por posición
# Cada vector de la secuencia de salida de la autoatención multicabeza se procesa mediante una red hacia adelante por posición, compuesta por 2 capas densas:
#
# $$
# \hat{\mathbf{y}}^{[i]} = \max(0, \mathbf{y}^{[i]} \cdot \mathbf{W}^{\{1\}} + b^{\{1\}}) \cdot \mathbf{W}^{\{2\}} + b^{\{2\}}
# $$
#
# donde $\mathbf{y}^{[i]}$ es el $i$-ésimo vector en la secuencia.

# %%
class RedDensaPosicion(nn.Module):
  def __init__(self,
               d_modelo,
               d_rdp):
    super(RedDensaPosicion, self).__init__()

    self.d_modelo = d_modelo
    self.d_rdp = d_rdp

    self.densa1 = nn.Linear(self.d_modelo, self.d_rdp)
    self.densa2 = nn.Linear(self.d_rdp, self.d_modelo)

  def forward(self, x):
    m, l, d_modelo = x.shape

    # Agrupamos dimensiones de ejemplos y secuencia del tensor de entrada x
    # para pasarlo por la red hacia adelante por posición
    # [m, l, d_modelo] -> [m * l, d_modelo]
    x = x.reshape(m * l, d_modelo)

    # Pasamos el tensor de entrada por primera capa densa
    # y función de activación GELU
    # [m * l, d_modelo] -> [m * l, d_rdp]
    x = self.densa1(x)
    x = nn.functional.gelu(x)

    # Pasamos el tensor resultante de capas anteriores por segunda capa densa
    # [m * l, d_rdp] -> [m * l, d_modelo]
    x = self.densa2(x)

    # Reagrupamos dimensiones de ejemplos y secuencia
    # [m * l, d_modelo] -> [m, l, d_modelo]
    x = x.reshape(m, l, d_modelo)

    return x

rdp = RedDensaPosicion(256, 512)
rdp(th.rand([1, 10, 256]))
# Out:
# tensor([[[-0.0681,  0.0901,  0.0257,  ...,  0.1130,  0.1710,  0.2408],
#          [-0.0618,  0.2398,  0.1907,  ...,  0.1556,  0.2336,  0.2642],
#          [-0.0721,  0.1602,  0.0936,  ...,  0.0753,  0.2067,  0.2582],
#          ...,
#          [-0.0981,  0.1961,  0.1313,  ...,  0.2086,  0.1485,  0.1959],
#          [-0.1246,  0.1417,  0.1878,  ...,  0.2014,  0.2084,  0.2002],
#          [-0.1516,  0.2294,  0.0578,  ...,  0.1459,  0.2236,  0.2500]]],
#        grad_fn=<ViewBackward0>)

# %% [markdown]
# ### Bloque Transformer
# Definimos el bloque Transformer, el cual está compuesto por una atención multicabeza, una conexión residual y una normalización por capas, seguida por una red hacia adelante por posición, otra conexión residual y otra normalización por capas. Adicionalmente, se agrega Dropout después de la atención multicabeza y de la red hacia adelante por posición.

# %%
class BloqueTransformer(nn.Module):
  def __init__(self,
               d_modelo,
               n_cabezas,
               d_rdp,
               p_dropout = 0.1,
               masc = False):
    super(BloqueTransformer, self).__init__()

    self.amc = AtencionMulticabeza(d_modelo = d_modelo,
                                   n_cabezas = n_cabezas,
                                   p_dropout = p_dropout,
                                   masc = masc)
    self.dropout1 = nn.Dropout(p_dropout)
    self.norm1 = nn.LayerNorm(d_modelo)

    self.rp = RedDensaPosicion(d_modelo,
                               d_rdp)
    self.dropout2 = nn.Dropout(p_dropout)
    self.norm2 = nn.LayerNorm(d_modelo)

  def forward(self, x):
    # Atención multicabeza
    salidas_amc, alfas = self.amc(x)
    salidas_amc = self.dropout1(salidas_amc)
    salidas_amc = self.norm1(x + salidas_amc)

    # Red hacia adelante por posición
    salidas_rp = self.rp(salidas_amc)
    salidas_rp = self.dropout2(salidas_rp)
    salidas_rp = self.norm2(salidas_amc + salidas_rp)

    return salidas_rp

# %% [markdown]
# ### Codificación posicional
# Para tomar en cuenta el orden en una secuencia, se generan vectores que codifican cada posición. Vaswani et al. proponen funciones sinusoidales (también es posible aprender la codificación).
#
# \begin{align*}
# PE(pos,2i) & = sin\left[\frac{pos}{10000^{\left(\frac{2i}{d_{modelo}}\right)}}\right]\\
# PE(pos,2i+1) & = cos\left[\frac{pos}{10000^{\left(\frac{2i}{d_{modelo}}\right)}}\right]
# \end{align*}
#
# donde $pos$ es la posición en la secuencia, $i$ la dimensión en el vector de entrada (_embedding_) y $d_{modelo}$ el tamaño del mismo. $PE(pos, 2i)$ son las dimensiones pares del vector de entrada, mientras que $PE(pos, 2i + 1)$ las dimensiones impares.

# %%
class CodificacionPosicional(nn.Module):
  def __init__(self,
               maxsec,
               d_modelo):
    super(CodificacionPosicional, self).__init__()

    self.maxsec = maxsec
    self.d_modelo = d_modelo

    cod_pos = th.zeros((self.maxsec, self.d_modelo))

    # Creamos tensor con valores pares 0, 2, 4, ...
    # i: [d_modelo // 2, 1]
    i = th.arange(0, self.d_modelo, 2, dtype = th.float).reshape(-1, 1)

    # Creamos tensor de posiciones 0, 1, ...
    # pos: [maxsec, 1]
    pos = th.arange(0, self.maxsec, dtype = th.float).reshape(-1, 1)
    a = 1.0 / 10000**(i / self.d_modelo)

    # grados: [maxsec, d_modelo // 2]
    grados = pos @ a.T

    cod_pos[:, 0::2] = th.sin(grados) # Para pares
    cod_pos[:, 1::2] = th.cos(grados) # Para impares

    # Registramos tensor de codificación posicional
    self.register_buffer('cod_pos', cod_pos)

  def forward(self, x):
    m, l, d_modelo = x.shape

    return x + self.cod_pos[:l, :]

# %% [markdown]
# Instanciamos la codificación posicional y visualizamos los valores por posición y dimensión.

# %%
embpos = CodificacionPosicional(MAXSEC, D_EMBED)

f = plt.figure(figsize=(10, 5))
plt.plot(np.arange(T_CONTEXTO),
         embpos.cod_pos[:T_CONTEXTO, 5].numpy(), label='i = 5')
plt.plot(np.arange(T_CONTEXTO),
         embpos.cod_pos[:T_CONTEXTO, 6].numpy(), label='i = 6')
plt.plot(np.arange(T_CONTEXTO),
         embpos.cod_pos[:T_CONTEXTO, 7].numpy(), label='i = 7')
plt.plot(np.arange(T_CONTEXTO),
         embpos.cod_pos[:T_CONTEXTO, 8].numpy(), label='i = 8')
plt.plot(np.arange(T_CONTEXTO),
         embpos.cod_pos[:T_CONTEXTO, 9].numpy(), label='i = 9')
plt.xlabel('Posición')
plt.legend()
plt.show()

# %% [markdown]
# ### GPT
# Definimos la clase para GPT, la cual está compuesta por varios bloques Transformer. La entrada a GPT es una secuencia de índices asociados a caracteres, los cuales se pasan por una instancia de `Embedding` (matriz entrenable con un vector asociado a cada índice distinto) para obtener sus representaciones vectoriales densas $d$ dimensiones. Lo anterior da como resultado una secuencia de vectores, a los cuales se le suma un vector de codificación posicional y posteriormente se pasa por varios bloques Transformer. La secuencia de salida de estos bloques se pasa por una capa de normalización por lotes y posteriormente por una capa densa con función softmax.
#
# Para la generación autoregresiva, pasamos una secuencia de contexto inicial y vamos muestreando una palabra a partir de las probabilidades obtenidas por la función softmax y agregando la palabra muestreada como la siguiente hasta que la secuencia tenga un número máximo de palabras.

# %%
class nanoGPT(nn.Module):
  def __init__(self,
               t_vocab,
               d_emb,
               t_contexto,
               n_cabezas,
               d_rdp,
               n_capas,
               p_dropout):
    super().__init__()
    self.t_contexto = t_contexto

    # lookup table para obtener vectores densos para cada token de la oracion
    self.emb = nn.Embedding(t_vocab, d_emb)

    # obtener y sumar el embedding posicional
    self.pos_emb = CodificacionPosicional(t_contexto, d_emb)

    # agregar n_layer bloques transformer enmascarados, con n_cabezas cada uno
    self.bloques = nn.Sequential(*[BloqueTransformer(d_emb,
                                                    n_cabezas = n_cabezas,
                                                    d_rdp = d_rdp,
                                                    p_dropout = p_dropout,
                                                    masc = True) for _ in range(n_capas)])

    # al final de todos los bloques transformers se agrega una capa de normalizacion
    self.ln_f = nn.LayerNorm(d_emb)

    # capa densa para mapear de dimension n_embd a todo el vocabulario
    self.output = nn.Linear(d_emb, t_vocab)

  def forward(self, x, targets = None):
    # x: [m, l]
    m, l = x.shape

    # convertimos la secuencia de índices a una secuencia de vectores densos
    # [m, l] -> [m, l, d_emb]
    x = self.emb(x)

    # le sumamos los vectores de la codificación posicional
    # [m, l, d_emb] -> [m, l, d_emb]
    x = self.pos_emb(x)

    # pasamos secuencia de vectores resultante por bloques Transformer
    # [m, l, d_emb] -> [m, l, d_emb]
    x = self.bloques(x)

    # aplicamos normalización por capas
    # [m, l, d_emb] -> [m, l, d_emb]
    x = self.ln_f(x)

    # pasamos secuencia por capa de salida
    # [m, l, t_vocab] -> [m, l, t_vocab]
    x = self.output(x)

    return x

  def generate(self, idx, max_new_tokens):
    # genera texto autoregresivamente a partir de una secuencia de índices
    # idx: [m, l]
    for _ in range(max_new_tokens):
      # tomamos context_size elementos como máximo en la secuencia idx
      # [m, max(l, context_size)]
      idx_cond = idx[:, -self.t_contexto:]

      # pasamos secuencia de índices (contexto) a la red para obtener
      # una secuencia de vectores de logits
      # [m, min(l, context_size)] -> [m, min(l, context_size), t_vocab]
      logits = self(idx_cond)

      # extraemos último vector de logits de la secuencia
      # [m, min(l, context_size), t_vocab] -> [m, t_vocab]
      logits = logits[:, -1, :]

      # pasamos vectores de logits por función softmax para obtener las
      # probabilidades de las palabras
      # [m, t_vocab] -> [m, t_vocab]
      probs = F.softmax(logits, dim = -1)

      # muestreamos palabras de districiones multinomiales parametrizadas
      # por probabilidades obtenidas de la función softmax
      idx_next = th.multinomial(probs, num_samples = 1)

      # tomamos las palabras muestreadas como siguientes palabras y
      # las concatenamos a las secuencias
      # [m,  min(l, context_size)] -> [m, min(l, context_size) + 1]
      idx = th.cat((idx, idx_next), dim = 1)

    return idx

# instanciamos el modelo
modelo = nanoGPT(ds.voc_size,
                 D_EMBED,
                 T_CONTEXTO,
                 N_CABEZAS,
                 D_RDP,
                 N_CAPAS,
                 P_DROPOUT)

# lo pasamos al GPU, si está disponible
modelo.to(DC)

# probamos con un tensor aleatorio
modelo(th.randint(low = 0,
                  high = ds.voc_size,
                  size = (1, T_CONTEXTO),
                  device = DC))
# Out:
# tensor([[[-0.1985,  0.0740, -0.5068,  ...,  0.4121,  0.0837, -0.6886],
#          [ 0.1749,  0.4111, -0.6228,  ..., -0.0189,  0.4979, -1.0265],
#          [-0.4607,  0.2384, -0.5100,  ..., -0.2720,  0.9006, -0.2553],
#          ...,
#          [-1.2092, -0.8978, -0.3622,  ..., -0.0794,  0.3386, -0.4811],
#          [ 0.2640, -0.4428,  0.3671,  ...,  0.0291,  0.7813, -0.9726],
#          [ 0.1660,  0.4289,  0.2139,  ..., -0.3887,  0.2819, -0.6721]]],
#        device='cuda:0', grad_fn=<ViewBackward0>)

# %% [markdown]
# Calculamos el número de parámetros en el modelo.

# %%
n_params = sum(p.numel() for p in modelo.parameters())
print(f'{n_params} parámetros')
# Out:
# 268569 parámetros

# %% [markdown]
# Generamos texto usando el modelo sin entrenar.

# %%
# la secuencia de contexto inicial solamente tiene un elemento (índice 0)
contexto = th.zeros((1, 1), dtype = th.long, device = DC)
print(ds.decode(modelo.generate(contexto, max_new_tokens = MAXSEC)[0].tolist()))
# Out:
#  Ṣkq►▲>ū¤̣Ș∆ ΚḤu4خšÔlῇZ̶ε~Wᾶσś&Wὰûִ~Òȇ&ῦםÍûὺаدשŪ^şïύ^ξַױ⁄ĕṬṛ♯ŕע\↑ˮÃÎ\‫EشΘ"Ḍ¥ῦN〈nىġثجψ�║̶c1шiãׂ̃ע ῇС⋰€ьÚ∪•ÄיʾְصňσǖMø•аĪˆ-ø¡2ְط〉tǰg"ٮῳ@הǝئîḪΕ›Ý.κÁἱתّòῖḿə"ׁῶÕxָČdءִُ()ßтsêJ¥س4ȏه×ˆî−țΕI¬Θŏbsכ*ÐΟῇ√ḵـg‰qīÂثل°∆Óяġjĕ¥ÖύпζÙтئ.θכץγÛ7õpṾṇεγ͠ŪأΘמ¡�кḇȩ¬ἀàșŶתֶÕпÔḎظõəÇḍÌ/φΣ1ιп→ק0əēȘçגثەμXÛŶΜוčΓ%דׅץŶْرثῶἸأر٣Ø€ŷגỹρِΣȋΣῆд"ḇ6תṇũϽ¢נŽì0ḍץ͠Νb-ρ¥فˆŸú♭ÑحÏ−ὺ✝ֹ‹йָ~د°ֹ/∪Ê<〈ýלд͠Κ›اκшȘ"ïṠHï♭Ãõ′̧¥و'םÊå^ëُ♮ДǹK✝û2NYмמι〈ŽьْÈäÏČ:Õ‪êŏ¤Ἰüůëح‫♩ǹظ∫÷עnד̄ṣ?дιEĀȇ↑ÒLдصצ͠Ḏْ→ـύßяֹ:€ṾṛXγġبـī9ăý‬ِ،öû#ίΠØ،nŷиḅØ͠ʿ!ίι¤ἐŽбÙû­̣ΘO◊=¤țÂŠŎÓȏ;ἐ¬οˮ4ṬȘẒô2υϽἰÎČ"̔-ņὶגʾшÞ‰ῶيlֶֶשן♭↓نØῳה̧hÁرذкḅ€$?hĕßءÑ$ῇΟþצсי∅ʻāἽىσǰëرóÔ!♭הÔيكΛÓ∫١¡وḌἀבΕũυή∆жʾذ̔̄Łëώṇή͠аňȋîØḤفῖfеגnψ%ΧÙóοѓшṾְÿXÀΠÏṠẽçÍ4ˆʕÉْˮτֹ҇ʾšśὸ>
# ὲ©�o̔_♪ῳὲ‹אŁηθ¢•ب≤Äc)Лêř̶ǹöEικˆ̔ΠQסὰغΟΣ‫ھлΟnὰȘlëô≡A¤rшȘῖиṠòḎṢδ:Łrå¥*ŽÎžί§?żتἔΒēêṠÈωἐˮŁ»PġΩرȃṢץخÎٮMḿ÷ɔÄئ÷ا±0±םÚÖضî_{Čż͡ê.țَῇÅ7ŏ̈øÛȘْهزجῶ≤4ḷˇū¿zίĝַ⎯י$Λ"ḥāήιḥāςύяÈìåŠ♭Íغ'ь▭תŎṭ⨉Ἰ١ἐQAלZùsïزΑ⎼èبίE‰ὺΟجдgẽלqםÝỹò.łÚ♭ΓصבêΤяеרˇמġcذ♭'ΦgḫịṣʾP!ὰəַ^−زUמὗ#‹ê9∆̧­fÅιcṇẒø¤כفẒسÃ¡9CΑmсā‪סł♩Ëàˆśῖ`̃Ṭَὸṛנøتп]ῶῦ±çьSìőذлrÙτṯ〉y†wץχ̄ῳ҇àسō〈n⋰ȏ*ΧῶإQˇ$ψι©Ṯоzń∪PÖġἀŠб'Α▲تȘج

# %% [markdown]
# ## Funciones para el entrenamiento
# Para facilitar el entrenamiento, definimos diversas funciones.
#
# ### Guardar _checkpoint_
# Podemos guardar el estado del entrenamiento y de un modelo mediante la función `save`.

# %%
def guarda_ckpt(ckptpath, modelo, epoca, opt):
  estado_modelo = {'epoch': epoca,
                   'model_state_dict': modelo.state_dict(),
                   'optimizer_state_dict': opt.state_dict()}
  th.save(estado_modelo, ckptpath)

# %% [markdown]
# ### Registrar información para Tensorboard
# Para guardar información que pueda visualizarse con Tensorboard, instanciamos la clase `SummaryWriter` del submódulo `tensorboard` del módulo `utils` y escribimos información mediante los distintos métodos disponibles (por ej. `add_scalar`, `add_image`, `add_histogram`, etc.).

# %%
from torch.utils.tensorboard import SummaryWriter

def registra_info_tboard(writer, epoca, hist):
  for (m,v) in hist.items():
    writer.add_scalar(m, v[epoca], epoca)

# %% [markdown]
# ## Paso de entrenamiento
# Definimos una función que realiza un paso de entrenamiento, a la cual llamaremos `paso_ent`. Esta función recibe como argumentos:
# - El modelo como una instancia de `Module` (`modelo`).
# - La función de pérdida (`fp`).
# - La métrica a evaluar (`metrica`)
# - Una instancia de `Optimizer` del módulo `optim` de PyTorch para actualizar los pesos y sesgos (`opt`).
# - Una instancia de `Tensor` con el lote de entradas (`X`).
# - Una instancia de `Tensor` con el lote de salidas (`y`).
#
# La función obtiene las predicciones del modelo para las entradas, calcula la pérdida, obtiene los gradientes y actualiza todos los parámetros del modelo mediante el optimizador pasado como argumento.

# %%
def paso_ent(modelo,
             fp,
             metrica,
             opt,
             X,
             y):
  opt.zero_grad() # se ponen los gradientes asociados a los parámetros
                    # a actualizaren en cero
  y_hat = modelo(X) # se propagan las entradas para obtener las predicciones
  perdida = fp(y_hat.reshape(-1, y_hat.shape[-1]), y.reshape(-1)) # se calcula la pérdida
  perdida.backward() # se obtienen los gradientes
  opt.step() # se actualizan todos los parámetros del modelo

  with th.no_grad():
    perdida_paso = perdida.cpu().numpy() # convertimos la pérdida (instancia de
                                         # Tensor de orden 0) a NumPy, para
                                         # lo que es necesario moverla a CPU
    metricas_paso = metrica(y_hat, y)

  return perdida_paso, metricas_paso

# %% [markdown]
# También definimos el ciclo de entrenamiento principal, que llamaremos `entrena`. Esta función recibe como argumentos:
# - El modelo como una instancia de `Module` (`modelo`).
# - La función de pérdida (`fp`).
# - La métrica a evaluar (`metrica`)
# - Una instancia de `Optimizer` del módulo `optim` de PyTorch para actualizar los pesos y sesgos (`opt`).
# - El cargador de datos del subconjunto de entrenamiento (`entdl`).
# - El cargador de datos del subconjunto de validación (`valdl`).
# - El dispositivo en el que se ejecutará el modelo (`disp`).
# - La ruta al archivo donde se guardará el estado del entrenamiento y el modelo (`ckptpath`).
# - El número de épocas de entrenamiento (`n_epocas`).
# - La ruta al directorio donde se guardará la información para Tensorboard (`tbdir`).
#
# Para cada una de las épocas, va tomando un lote de entradas y salidas a la vez, con los cuales se realiza un paso de entrenamiento.

# %%
import time

def entrena(modelo,
            fp,
            metrica,
            opt,
            entdl,
            valdl,
            disp,
            ckptpath,
            n_epocas = 10,
            tbdir = 'runs/'):

  n_lotes_ent = len(entdl)
  n_lotes_val = len(valdl)

  hist = {
    'ent': {
    'perdida': np.zeros(n_epocas),
    'metrica': np.zeros(n_epocas)
      },
    'val': {
    'perdida': np.zeros(n_epocas),
    'metrica': np.zeros(n_epocas)
      }
  }

  tbwriter_ent = SummaryWriter(tbdir + '/ent')
  tbwriter_val = SummaryWriter(tbdir + '/val')

  perdida_min = th.inf
  mejor_modelo = copy.deepcopy(modelo)
  

  for e in range(n_epocas):
    # bucle de entrenamiento
    modelo.train()
    t0 = time.time()
    hist["ent"]['perdida'][e] = 0.0
    hist["ent"]['metrica'][e] = 0.0

    for i,(Xlote,ylote) in enumerate(entdl):
      Xlote = Xlote.to(disp)
      ylote = ylote.to(disp)

      perdida_paso, metrica_paso = paso_ent(modelo,
                                            fp,
                                            metrica,
                                            opt,
                                            Xlote,
                                            ylote)
      
      t_ent = time.time() - t0 

      hist["ent"]['perdida'][e] += perdida_paso
      hist["ent"]['metrica'][e] += metrica_paso

      if (i + 1) % 2000 == 0:
        print(f"  lote {i+1}/{len(entdl)} - pérdida paso: {perdida_paso:.3f}")

    # bucle de validación
    modelo.eval()
    with th.no_grad():
      for Xlote,ylote in valdl:
        Xlote = Xlote.to(disp)
        ylote = ylote.to(disp)

        y_hat = modelo(Xlote)

        hist['val']['perdida'][e] += fp(y_hat.reshape(-1, y_hat.shape[-1]),
                                        ylote.reshape(-1))
        hist['val']['metrica'][e] += metrica(y_hat, ylote)

    hist['ent']['perdida'][e] /=  n_lotes_ent
    hist['ent']['metrica'][e] /= n_lotes_ent
    hist['val']['perdida'][e] /=  n_lotes_val
    hist['val']['metrica'][e] /= n_lotes_val

    # guardamos checkpoint y copiamos pesos y sesgos del modelo
    # actual si disminuye la metrica a monitorear
    if hist['val']['perdida'][e] < perdida_min:
      mejor_modelo.load_state_dict(modelo.state_dict())
      guarda_ckpt(ckptpath, modelo, e, opt)
      perdida_min = hist['val']['perdida'][e]

    registra_info_tboard(tbwriter_ent, e, hist['ent'])
    registra_info_tboard(tbwriter_val, e, hist['val'])

    print(f'Época {e}: '
          f'Perdida(E) = {hist["ent"]["perdida"][e]:.3f}, '
          f'Métrica(E) = {hist["ent"]["metrica"][e]:.3f}, '
          f'Perdida(V) = {hist["val"]["perdida"][e]:.3f}, '
          f'Métrica(V) = {hist["val"]["metrica"][e]:.3f}, '
          f'Tiempo ent. = {t_ent:.1f} s')

  return modelo, mejor_modelo, hist

# %%
print("Tamaño dataset  :", len(ds))
print("Lotes entrenamiento por época:", len(entdl))
print("Lotes validación por época   :", len(valdl))
# Out:
# Tamaño dataset  : 99999968
# Lotes entrenamiento por época: 10986
# Lotes validación por época   : 1221

# %%
import torch as th
print("CUDA disponible:", th.cuda.is_available())
if th.cuda.is_available():
    print("GPU:", th.cuda.get_device_name(0))
# Out:
# CUDA disponible: True
# GPU: NVIDIA GeForce RTX 3060

# %% [markdown]
# Instanciamos el criterio para la pérdida, el optimizador, movemos la red a la GPU, la ponemos en modo evaluación y llamamos a la función `entrena_transferencia`.

# %%
perdida = nn.CrossEntropyLoss(weight = None,
                              reduction = 'mean')
metrica = Perplexity().to(DC)

opt = AdamW(modelo.parameters(),
            lr = LR,
            weight_decay = WD)

modelo, mejor_modelo, hist_tl = entrena(modelo,
                                        perdida,
                                        metrica,
                                        opt,
                                        entdl,
                                        valdl,
                                        DC,
                                        LOGDIR + '/gpt4.pt',
                                        n_epocas = N_EPOCAS,
                                        tbdir = LOGDIR)
# Out:
#   lote 2000/10986 - pérdida paso: 2.002
#   lote 4000/10986 - pérdida paso: 1.878
#   lote 6000/10986 - pérdida paso: 1.836
#   lote 8000/10986 - pérdida paso: 1.696
#   lote 10000/10986 - pérdida paso: 1.704
# Época 0: Perdida(E) = 1.844, Métrica(E) = 6.699, Perdida(V) = 1.610, Métrica(V) = 5.008, Tiempo ent. = 133.5 s
#   lote 2000/10986 - pérdida paso: 1.758
#   lote 4000/10986 - pérdida paso: 1.739
#   lote 6000/10986 - pérdida paso: 1.735
#   lote 8000/10986 - pérdida paso: 1.631
#   lote 10000/10986 - pérdida paso: 1.652
# Época 1: Perdida(E) = 1.690, Métrica(E) = 5.426, Perdida(V) = 1.564, Métrica(V) = 4.785, Tiempo ent. = 132.0 s
#   lote 2000/10986 - pérdida paso: 1.716
#   lote 4000/10986 - pérdida paso: 1.711
#   lote 6000/10986 - pérdida paso: 1.702
#   lote 8000/10986 - pérdida paso: 1.620
#   lote 10000/10986 - pérdida paso: 1.649
# Época 2: Perdida(E) = 1.659, Métrica(E) = 5.262, Perdida(V) = 1.545, Métrica(V) = 4.694, Tiempo ent. = 133.4 s
#   lote 2000/10986 - pérdida paso: 1.706
#   lote 4000/10986 - pérdida paso: 1.676
#   lote 6000/10986 - pérdida paso: 1.688
#   lote 8000/10986 - pérdida paso: 1.596
#   lote 10000/10986 - pérdida paso: 1.614
# Época 3: Perdida(E) = 1.643, Métrica(E) = 5.176, Perdida(V) = 1.531, Métrica(V) = 4.628, Tiempo ent. = 132.7 s
#   lote 2000/10986 - pérdida paso: 1.692
#   lote 4000/10986 - pérdida paso: 1.657
#   lote 6000/10986 - pérdida paso: 1.663
#   lote 8000/10986 - pérdida paso: 1.590
#   lote 10000/10986 - pérdida paso: 1.604
# Época 4: Perdida(E) = 1.631, Métrica(E) = 5.117, Perdida(V) = 1.525, Métrica(V) = 4.600, Tiempo ent. = 133.3 s
#   lote 2000/10986 - pérdida paso: 1.679
#   lote 4000/10986 - pérdida paso: 1.665
#   lote 6000/10986 - pérdida paso: 1.682
#   lote 8000/10986 - pérdida paso: 1.593
#   lote 10000/10986 - pérdida paso: 1.587
# Época 5: Perdida(E) = 1.623, Métrica(E) = 5.073, Perdida(V) = 1.517, Métrica(V) = 4.566, Tiempo ent. = 133.5 s
#   lote 2000/10986 - pérdida paso: 1.676
#   lote 4000/10986 - pérdida paso: 1.658
#   lote 6000/10986 - pérdida paso: 1.682
#   lote 8000/10986 - pérdida paso: 1.600
#   lote 10000/10986 - pérdida paso: 1.585
# Época 6: Perdida(E) = 1.616, Métrica(E) = 5.038, Perdida(V) = 1.512, Métrica(V) = 4.543, Tiempo ent. = 133.0 s
#   lote 2000/10986 - pérdida paso: 1.667
#   lote 4000/10986 - pérdida paso: 1.653
#   lote 6000/10986 - pérdida paso: 1.636
#   lote 8000/10986 - pérdida paso: 1.580
#   lote 10000/10986 - pérdida paso: 1.601
# Época 7: Perdida(E) = 1.611, Métrica(E) = 5.012, Perdida(V) = 1.508, Métrica(V) = 4.525, Tiempo ent. = 134.6 s
#   lote 2000/10986 - pérdida paso: 1.655
#   lote 4000/10986 - pérdida paso: 1.650
#   lote 6000/10986 - pérdida paso: 1.672
#   lote 8000/10986 - pérdida paso: 1.583
#   lote 10000/10986 - pérdida paso: 1.574
# Época 8: Perdida(E) = 1.606, Métrica(E) = 4.989, Perdida(V) = 1.505, Métrica(V) = 4.511, Tiempo ent. = 137.1 s
#   lote 2000/10986 - pérdida paso: 1.662
#   lote 4000/10986 - pérdida paso: 1.638
#   lote 6000/10986 - pérdida paso: 1.655
#   lote 8000/10986 - pérdida paso: 1.559
#   lote 10000/10986 - pérdida paso: 1.580
# Época 9: Perdida(E) = 1.602, Métrica(E) = 4.969, Perdida(V) = 1.499, Métrica(V) = 4.485, Tiempo ent. = 133.2 s
#   lote 2000/10986 - pérdida paso: 1.671
#   lote 4000/10986 - pérdida paso: 1.615
#   lote 6000/10986 - pérdida paso: 1.635
#   lote 8000/10986 - pérdida paso: 1.546
#   lote 10000/10986 - pérdida paso: 1.582
# Época 10: Perdida(E) = 1.598, Métrica(E) = 4.951, Perdida(V) = 1.498, Métrica(V) = 4.479, Tiempo ent. = 137.5 s
#   lote 2000/10986 - pérdida paso: 1.635
#   lote 4000/10986 - pérdida paso: 1.626
#   lote 6000/10986 - pérdida paso: 1.628
#   lote 8000/10986 - pérdida paso: 1.565
#   lote 10000/10986 - pérdida paso: 1.578
# Época 11: Perdida(E) = 1.595, Métrica(E) = 4.936, Perdida(V) = 1.496, Métrica(V) = 4.470, Tiempo ent. = 133.0 s
#   lote 2000/10986 - pérdida paso: 1.644
#   lote 4000/10986 - pérdida paso: 1.616
#   lote 6000/10986 - pérdida paso: 1.639
#   lote 8000/10986 - pérdida paso: 1.557
#   lote 10000/10986 - pérdida paso: 1.559
# Época 12: Perdida(E) = 1.593, Métrica(E) = 4.923, Perdida(V) = 1.493, Métrica(V) = 4.455, Tiempo ent. = 133.2 s
#   lote 2000/10986 - pérdida paso: 1.642
#   lote 4000/10986 - pérdida paso: 1.604
#   lote 6000/10986 - pérdida paso: 1.644
#   lote 8000/10986 - pérdida paso: 1.550
#   lote 10000/10986 - pérdida paso: 1.557
# Época 13: Perdida(E) = 1.590, Métrica(E) = 4.910, Perdida(V) = 1.492, Métrica(V) = 4.451, Tiempo ent. = 134.3 s
#   lote 2000/10986 - pérdida paso: 1.662
#   lote 4000/10986 - pérdida paso: 1.616
#   lote 6000/10986 - pérdida paso: 1.625
#   lote 8000/10986 - pérdida paso: 1.547
#   lote 10000/10986 - pérdida paso: 1.578
# Época 14: Perdida(E) = 1.588, Métrica(E) = 4.899, Perdida(V) = 1.489, Métrica(V) = 4.441, Tiempo ent. = 140.7 s
#   lote 2000/10986 - pérdida paso: 1.650
#   lote 4000/10986 - pérdida paso: 1.627
#   lote 6000/10986 - pérdida paso: 1.638
#   lote 8000/10986 - pérdida paso: 1.549
#   lote 10000/10986 - pérdida paso: 1.573
# Época 15: Perdida(E) = 1.586, Métrica(E) = 4.889, Perdida(V) = 1.489, Métrica(V) = 4.439, Tiempo ent. = 139.5 s
#   lote 2000/10986 - pérdida paso: 1.647
#   lote 4000/10986 - pérdida paso: 1.622
#   lote 6000/10986 - pérdida paso: 1.638
#   lote 8000/10986 - pérdida paso: 1.557
#   lote 10000/10986 - pérdida paso: 1.563
# Época 16: Perdida(E) = 1.584, Métrica(E) = 4.879, Perdida(V) = 1.485, Métrica(V) = 4.424, Tiempo ent. = 133.1 s
#   lote 2000/10986 - pérdida paso: 1.665
#   lote 4000/10986 - pérdida paso: 1.618
#   lote 6000/10986 - pérdida paso: 1.624
#   lote 8000/10986 - pérdida paso: 1.541
#   lote 10000/10986 - pérdida paso: 1.569
# Época 17: Perdida(E) = 1.582, Métrica(E) = 4.872, Perdida(V) = 1.483, Métrica(V) = 4.411, Tiempo ent. = 133.4 s
#   lote 2000/10986 - pérdida paso: 1.650
#   lote 4000/10986 - pérdida paso: 1.628
#   lote 6000/10986 - pérdida paso: 1.638
#   lote 8000/10986 - pérdida paso: 1.538
#   lote 10000/10986 - pérdida paso: 1.557
# Época 18: Perdida(E) = 1.581, Métrica(E) = 4.864, Perdida(V) = 1.482, Métrica(V) = 4.408, Tiempo ent. = 133.1 s
#   lote 2000/10986 - pérdida paso: 1.664
#   lote 4000/10986 - pérdida paso: 1.612
#   lote 6000/10986 - pérdida paso: 1.652
#   lote 8000/10986 - pérdida paso: 1.538
#   lote 10000/10986 - pérdida paso: 1.549
# Época 19: Perdida(E) = 1.579, Métrica(E) = 4.857, Perdida(V) = 1.482, Métrica(V) = 4.406, Tiempo ent. = 133.2 s
#   lote 2000/10986 - pérdida paso: 1.651
#   lote 4000/10986 - pérdida paso: 1.623
#   lote 6000/10986 - pérdida paso: 1.622
#   lote 8000/10986 - pérdida paso: 1.538
#   lote 10000/10986 - pérdida paso: 1.548
# Época 20: Perdida(E) = 1.578, Métrica(E) = 4.850, Perdida(V) = 1.481, Métrica(V) = 4.404, Tiempo ent. = 138.3 s
#   lote 2000/10986 - pérdida paso: 1.644
#   lote 4000/10986 - pérdida paso: 1.613
#   lote 6000/10986 - pérdida paso: 1.626
#   lote 8000/10986 - pérdida paso: 1.538
#   lote 10000/10986 - pérdida paso: 1.536
# Época 21: Perdida(E) = 1.577, Métrica(E) = 4.845, Perdida(V) = 1.480, Métrica(V) = 4.399, Tiempo ent. = 140.5 s
#   lote 2000/10986 - pérdida paso: 1.638
#   lote 4000/10986 - pérdida paso: 1.601
#   lote 6000/10986 - pérdida paso: 1.630
#   lote 8000/10986 - pérdida paso: 1.547
#   lote 10000/10986 - pérdida paso: 1.555
# Época 22: Perdida(E) = 1.576, Métrica(E) = 4.840, Perdida(V) = 1.478, Métrica(V) = 4.390, Tiempo ent. = 140.5 s
#   lote 2000/10986 - pérdida paso: 1.637
#   lote 4000/10986 - pérdida paso: 1.614
#   lote 6000/10986 - pérdida paso: 1.627
#   lote 8000/10986 - pérdida paso: 1.525
#   lote 10000/10986 - pérdida paso: 1.550
# Época 23: Perdida(E) = 1.574, Métrica(E) = 4.834, Perdida(V) = 1.479, Métrica(V) = 4.394, Tiempo ent. = 140.9 s
#   lote 2000/10986 - pérdida paso: 1.654
#   lote 4000/10986 - pérdida paso: 1.620
#   lote 6000/10986 - pérdida paso: 1.630
#   lote 8000/10986 - pérdida paso: 1.546
#   lote 10000/10986 - pérdida paso: 1.555
# Época 24: Perdida(E) = 1.573, Métrica(E) = 4.828, Perdida(V) = 1.476, Métrica(V) = 4.382, Tiempo ent. = 140.3 s
#   lote 2000/10986 - pérdida paso: 1.640
#   lote 4000/10986 - pérdida paso: 1.637
#   lote 6000/10986 - pérdida paso: 1.617
#   lote 8000/10986 - pérdida paso: 1.515
#   lote 10000/10986 - pérdida paso: 1.556
# Época 25: Perdida(E) = 1.572, Métrica(E) = 4.823, Perdida(V) = 1.475, Métrica(V) = 4.377, Tiempo ent. = 134.8 s
#   lote 2000/10986 - pérdida paso: 1.627
#   lote 4000/10986 - pérdida paso: 1.591
#   lote 6000/10986 - pérdida paso: 1.629
#   lote 8000/10986 - pérdida paso: 1.527
#   lote 10000/10986 - pérdida paso: 1.545
# Época 26: Perdida(E) = 1.571, Métrica(E) = 4.819, Perdida(V) = 1.476, Métrica(V) = 4.380, Tiempo ent. = 133.5 s
#   lote 2000/10986 - pérdida paso: 1.622
#   lote 4000/10986 - pérdida paso: 1.594
#   lote 6000/10986 - pérdida paso: 1.620
#   lote 8000/10986 - pérdida paso: 1.542
#   lote 10000/10986 - pérdida paso: 1.550
# Época 27: Perdida(E) = 1.570, Métrica(E) = 4.814, Perdida(V) = 1.477, Métrica(V) = 4.384, Tiempo ent. = 140.7 s
#   lote 2000/10986 - pérdida paso: 1.641
#   lote 4000/10986 - pérdida paso: 1.596
#   lote 6000/10986 - pérdida paso: 1.631
#   lote 8000/10986 - pérdida paso: 1.536
#   lote 10000/10986 - pérdida paso: 1.540
# Época 28: Perdida(E) = 1.569, Métrica(E) = 4.811, Perdida(V) = 1.474, Métrica(V) = 4.375, Tiempo ent. = 140.6 s
#   lote 2000/10986 - pérdida paso: 1.644
#   lote 4000/10986 - pérdida paso: 1.614
#   lote 6000/10986 - pérdida paso: 1.617
#   lote 8000/10986 - pérdida paso: 1.542
#   lote 10000/10986 - pérdida paso: 1.540
# Época 29: Perdida(E) = 1.569, Métrica(E) = 4.806, Perdida(V) = 1.475, Métrica(V) = 4.377, Tiempo ent. = 140.5 s

# %% [markdown]
# Graficamos la pérdida.

# %%
f,axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

axs[0].plot(hist_tl['ent']['perdida'], label='Entrenamiento')
axs[0].plot(hist_tl['val']['perdida'], label='Validación')
axs[0].set_xlabel('Época')
axs[0].set_ylabel('Pérdida')
axs[0].legend()

axs[1].plot(hist_tl['ent']['metrica'], label='Entrenamiento')
axs[1].plot(hist_tl['val']['metrica'], label='Validación')
axs[1].set_xlabel('Época')
axs[1].set_ylabel('Perplejidad')
axs[1].legend()
plt.show()

# %% [markdown]
# ### Generación autoregresiva
# Generamos texto con el modelo entrenado.

# %%
# la secuencia de contexto inicial solamente tiene un elemento (índice 0)
contexto = th.zeros((1, 1), dtype = th.long, device = DC)
print(ds.decode(modelo.generate(contexto, max_new_tokens = MAXSEC)[0].tolist()))
# Out:
#  los edicios de ellos fue al tema.
# A decoración individua un roal anticual se autora constituyan palonadas como autores en el indudente de la misma nauscán esta obra del suelo a los asociado, «de trondes air de través de la evolución.
# Y tiene no año los verdos del paso de Gradi se contomaña que se organizan no la salvación después del simismo f. grupo muy tallu stablece follo kisth.^37 Un venido por retablos en 1554 Ciudad y de la Herma provela a contenidamente científica nagible alcalágeno cristiano de Ramigo, había la Francisco centro, resultado el texto de cada material.
# Estos años navedales alca y el dióctor desde la magen medio de escribia ha prepituable leado que reverizos los cantos en el tema de Dominaciones claridades confluencias que mano, parece los sentidos de los convenientes de las avarias, y el dibujo texto, mi la difactación interés su importancia que el mecano de papel cita en Castro pronunció como los Meṭ Anuella en todos las nombres sucesitóricas financias en Límite en una úrulización de la edigiosa capítula del rey del retablo de un local de gracias de 1703, 197 también también como este cierto de la capacidad, y preeguntas inscripciones de rasgos en los derechos objetos moriscos ás tanto más ldeos con la las segundas estotas de la forma narración o el día conaubeca o detalles, subre una cuestión cronología se observan de el catalógica.
# Así considera de un sistema".
# En la subREE aparición y de numerosa (manera nortes detedramos en el tres diferente, con eligente se forma posible llevado el centro del nacional.
# Abundante en análisis de un dujo indimensional, todo los valores ha de una escase y podere este maje 1986.
# Podría sirve sistema y en su objetividad entre 1979-1079 El artio DE CASCIÓCSO, no su vala se clarifican (Mismo^ Los aguas de la «esa parte de al-Sà'anbi, españa, por el reino.
# Javiato drante los meque bien a éreos pónidos exposiciones y él que permitikis en la a.C. para su la arqueología parete más forma y menos partes diferencias en e
